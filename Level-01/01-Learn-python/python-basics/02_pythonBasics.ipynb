# %%
a = 4
id(a)
# Out:
# 11654472

# %%
id(4)
# Out:
# 11654472

# %%
hex(11654472)
# Out:
# '0xb1d548'

# %%
# aliasing
id(a)
b = a
id(b)
# Out:
# 11654472

# %%
c = b
id(c)
# Out:
# 11654472

# %%
del a

# %%
id(b)
# Out:
# 11654472

# %%
print(b)
# Out:
# 4

# %%
import sys
a = "corona"
b = a
c = b

# %%
id(a)
# Out:
# 133192489642400

# %%
id(b)
# Out:
# 133192489642400

# %%
id(c)
# Out:
# 133192489642400

# %%
sys.getrefcount(a)
# Out:
# 4

# %%
a
# Out:
# 'corona'

# %%
b
# Out:
# 'corona'

# %%
b
# Out:
# 'corona'

# %%
a = "prachi"

b = a
c = b

# %%
sys.getrefcount(a)
# Out:
# 4

# %%
# wierd behaviour
a = 2
b = a
c = b

# %%
sys.getrefcount(a)
# Out:
# 4294967295

# %%
a = 1008979
b = a
c = b

# %%
sys.getrefcount(a)
# Out:
# 4

# %%
a = 256
b = 256
id(a)
# Out:
# 11662536

# %%
id(b)
# Out:
# 11662536

# %%
# -5 to 256 their ids are same
a = -5
b = -5
id(a)
# Out:
# 11654184

# %%
id(b)
# Out:
# 11654184

# %%
a =  257
b = 257
id(a)
# Out:
# 133192489522704

# %%
id(b)
# Out:
# 133192489520816

# %%
a = "prachi"
b = "prachi"
id(a)
# Out:
# 133192490057872

# %%
id(b)
# Out:
# 133192490057872

# %%
a = "rcoem technology"
b = "rcoem technology"
id(a)
# Out:
# 133192490035056

# %%
id(b)
# Out:
# 133192490035312

# %%
a = "rcoem_technology"
b = "rcoem_technology"
id(a)
# Out:
# 133192490037552

# %%
id(b)
# Out:
# 133192490037552

# %%
#python wierd behaviour
# 1. getrefcount anomaly
# 2. -5 to 256
# 3. string

# %%
l = [1,2,3]
l
# Out:
# [1, 2, 3]

# %%
id(l)
# Out:
# 133192490036160

# %%
id(1)
# Out:
# 11654376

# %%
id(l[0])
# Out:
# 11654376

# %%
#immutable datatype : adress changes
a = (1,2,3)
id(a)
# Out:
# 135845798908032

# %%
a = a + (4,5)
id(a)
# Out:
# 135845946885216

# %%
#mutable data type :
l = [1,2,3]
id(l)
# Out:
# 135845799164928

# %%
l.append(4)
id(l)
# Out:
# 135845799164928

# %%
l1 = l
id(l1)
# Out:
# 135845799164928

# %%
# it adress original list to avoid this we use cloning
l1 = l[:]
id(l1)
# now it is adressing different memory location
# Out:
# 135845799185152

# %%
a = [1,2,3,[4,5]]
a[-1][-1] = 500

# %%
a
# Out:
# [1, 2, 3, [4, 500]]

# %%
a = [1,2]
id(a)
# Out:
# 135845799086912

# %%
b = [3,4]
c = (a,b)
c[0][0] = 100
c
# Out:
# ([100, 2], [3, 4])

# %%
id(a)
# Out:
# 135845799086912

# %%
id(b)
# Out:
# 135845799575104

# %%
id(c)
# Out:
# 135845799120000

# %%
a = a + [5,6]

# %%
c # no change in c
# Out:
# ([100, 2], [3, 4])
