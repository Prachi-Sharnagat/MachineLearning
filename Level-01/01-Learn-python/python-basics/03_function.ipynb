# %%
# from is_Even import is_even as even

# print(even(8))

# %%
def power(a,b):
  return a**b;
power(2,2)
# Out:
# 4

# %%
# use try and catch to avoid errors
# so we can do

def power(a=1, b=2): #default argument are taken when value is not given
  return a**b;

power(1)
# Out:
# 1

# %%
power()
# Out:
# 1

# %%
power(b=2, a=3)
# Out:
# 9

# %%
def flexi(*number):

  product = 1
  print(type(number))
  for i in number:

    product = product*i

  print(product)

# %%
flexi([1,2,3])
# Out:
# <class 'tuple'>
# [1, 2, 3]

# %%
flexi([1,2,4,5]) #this is how print work
# Out:
# <class 'tuple'>
# [1, 2, 4, 5]

# %%
flexi((1,2,3))
# Out:
# <class 'tuple'>
# (1, 2, 3)

# %%
type(flexi)
# Out:
# function

# %%
def func_a():
  print("inside function a")

def func_b(y):
  print("iside functionb")
  return y

print(func_a())
print(5+ func_b(2))
# Out:
# inside function a
# None
# iside functionb
# 7

# %%
def f(y):
  x = 1
  x +=1
  print(x)

x=5
f(x)
print(x)
# Out:
# 2
# 5

# %%
def f(y):

  print(x)
  print(x+1)
x =  5
f(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
def f(y):
  x += 1;

x = 5;
f(x);
print(x); # throw error we cannot change x their
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-197833054.py in <cell line: 0>()
#       3
#       4 x = 5;
# ----> 5 f(x);
#       6 print(x);
#
# /tmp/ipython-input-197833054.py in f(y)
#       1 def f(y):
# ----> 2   x += 1;
#       3
#       4 x = 5;
#       5 f(x);
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
#global changes by
def h(y):

  global x;
  x+=1;
x = 5
h(x)
print(x)
# Out:
# 6

# %%
def f(x):
  print('in f(x) : x =', x )
  x = x + 1;
  return x
x = 3
z = f(x)
print('in main program scope : z =', z )
print('in main program scope : x =', x )
# Out:
# in f(x) : x = 3
# in main program scope : z = 4
# in main program scope : x = 3

# %%
# nnested function
def f():

  print("inside f")

  def g():

    print("inside g")
  g()

# %%
f()
# Out:
# inside f
# inside g

# %%
# g() error throw

# %%
# nnested function
def f():
  print("inside f")

  def g():
    print("inside g")
    f()
  g()

# %%
def g(x):
  def h():
    x = 'abc'
  x +=1
  print('in function h x = ', x)
  h()
  return x
x = 3
z = g(x)
# Out:
# in function h x =  4

# %%
def g(x):
  def h(x):
    x = x+1
    print('in function h()x x = ', x)
  x +=1
  print('in function g()x x = ', x)
  h(x)
  return x
x = 3
z = g(x)

print("in main f x = ", x)
print('in main fuction z = ', z)
# Out:
# in function g()x x =  4
# in function h()x x =  5
# in main f x =  3
# in main fuction z =  4

# %%
#function as objects

def f(num):
    return num**2

# %%
f(4)
x = f

# %%
del f

# %%
# f(8) // throw error because f is deleted

# %%
x(2)
# Out:
# 4

# %%
x(6)
# Out:
# 36

# %%
# x stored function (call by reference)
type(x)
# Out:
# function

# %%
l =[1,2,3]

# %%
l = [1,2,3,4,x]

# %%
l
# Out:
# [1, 2, 3, 4, <function __main__.f(num)>]

# %%
l[-1](3)
# Out:
# 9

# %%
l
# Out:
# [1, 2, 3, 4, <function __main__.f(num)>]

# %%
l = [1,2,3,4,x(5)]

# %%
l
# Out:
# [1, 2, 3, 4, 25]

# %%
def func_a():
  print("inside a")

def func_c(z):
  print("inside c")
  return z();

print(func_c(func_a))
# Out:
# inside c
# inside a
# None

# %%
def f():
  def x(a,b):
    return a+b;
  return x;

val = f()(3,4)
print(val)
# Out:
# 7
