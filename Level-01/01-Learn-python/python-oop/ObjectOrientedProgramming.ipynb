# %%
# everything in python is object

# class -> data and behaviour
# class name should be PascalCase
class Car:
  color = "blue"
  brand = "bmw"

# %%
l = [1,2,3]
# feature to make object easily --> object literal
# or we can make
l = list()

# %%
l.append(2)

# %%
l
# Out:
# [2]

# %%
city = str()

# %%
# from fileName import Atm
# sbi = Atm() //it will print hello world

# %%
# a construuctor is a special method which automatically runs when you create object of a class

# %%
# eg of constuctor
class Students :
  def __init__(self, name, roll_no):
    self.name = name
    self.roll_no = roll_no

s1 = Students("prachi", 18)
print(s1.name)
print(s1.roll_no)
# Out:
# prachi
# 18

# %%
class Demo:
  def __init__(self):
    print("hello world")

s2 = Demo()
# print(s1)
# Out:
# hello world

# %%
# eg of constuctor
class Students :
  def __init__(self, name="unknown", roll_no = 16):
    self.name = name
    self.roll_no = roll_no

s1 = Students("prachi", 18)
print(s1.name)
print(s1.roll_no)
# Out:
# prachi
# 18

# %%
s2 = Students()
print(s2.name)
print(s2.roll_no)
# Out:
# unknown
# 16

# %%
# atm code :

class Atm :
  # constructore --> init (special method exceute itself )
  def __init__(self):
    self.__pin = ''
    self.__balance = 0
    self.__menu()
  def __menu(self):
      user_input = int(input('''
      Hello, how would you like to proceed ?
      1. enter 1 to create pin
      2. enter 2 to deposite
      3. enter 3 to withdraw
      4. enter 4 to check balance
      5. enter 5 to exit

      '''))
      if user_input == 1:
        print("create pin")
        self.create_pin()
      elif user_input == 2:
        print("deposite ")
        self.deposite()
      elif user_input == 3:
        print("withdraw")
        self.withdraw()
      elif user_input ==4 :
        print("check balance")
        self.check_balance()
      else:
        print('''
        exit''')

  def get_pin(self):
    return self.__pin

  def set_pin(self, new_pin):
      if type(new_pin) == int:
        self.__pin = new_pin
        print("pin updated")
      else:
        print("error!")


  def create_pin(self):
     self.__pin = input("enter your pin : ")
     print("pin set successfully ")
     self.__menu()


  def deposite(self):
    temp = input("enter your pin :")
    if temp == self.__pin:
        amount = int(input("enter the amount : "))
        self.__balance = self.__balance +  amount
        print("deposite successful")
    else :
        print("invalid pin")
    self.__menu()

  def withdraw(self):
    temp = input("enter your pin : ")
    if  temp == self.__pin:
        amount = int(input("enter the amount : "))
        if amount < self.__balance :
         self.__balance = self.__balance -  amount
         print("withdraw successful")
        else :
          print("not sufficient amount")
    else :
        print("invalid pin")
    self.__menu()

  def check_balance(self):
     temp = input("enter your pin : ")
     if  temp == self.__pin:
         print(self.__balance)
     else :
       print("invalid pin")
     self.__menu()

# %%
check_atm =  Atm()
# Out:
#       Hello, how would you like to proceed ?
#       1. enter 1 to create pin
#       2. enter 2 to deposite
#       3. enter 3 to withdraw
#       4. enter 4 to check balance
#       5. enter 5 to exit
#
#       5
#
#         exit

# %%
check_atm.get_pin()
# Out:
# ''

# %%
check_atm.set_pin("100")
# Out:
# error!

# %%
check_atm.get_pin()
# Out:
# ''

# %%
check_atm.deposite()
check_atm.__balance = "hello"
# check_atm.menu // lets make menu method private use __
check_atm._Atm__pin = '123'
# Out:
# enter your pin :
# invalid pin
#
#       Hello, how would you like to proceed ?
#       1. enter 1 to create pin
#       2. enter 2 to deposite
#       3. enter 3 to withdraw
#       4. enter 4 to check balance
#       5. enter 5 to exit
#
#       2
# deposite
# enter your pin :
# invalid pin
#
#       Hello, how would you like to proceed ?
#       1. enter 1 to create pin
#       2. enter 2 to deposite
#       3. enter 3 to withdraw
#       4. enter 4 to check balance
#       5. enter 5 to exit
#
#       2
# deposite
# enter your pin :123
# enter the amount : 10
# deposite successful
#
#       Hello, how would you like to proceed ?
#       1. enter 1 to create pin
#       2. enter 2 to deposite
#       3. enter 3 to withdraw
#       4. enter 4 to check balance
#       5. enter 5 to exit
#
#       5
#
#         exit

# %%
check_atm.check_balance()
# Out:
# enter your pin :
# 123010
#
#       Hello, how would you like to proceed ?
#       1. enter 1 to create pin
#       2. enter 2 to deposite
#       3. enter 3 to withdraw
#       4. enter 4 to check balance
#       5. enter 5 to exit
#
#       5
#
#         exit

# %%
class Car:
    def __init__(self, brand, color):
        self.brand = brand  # 'self.brand' belongs to the object
        self.color = color  # 'brand' is just a temporary argument

# %%
mycar = Car("bmw", "black")

# %%
print(mycar.brand)
id(mycar)
# Out:
# bmw
# 136460797982192

# %%
#fraction class
class Fraction :
  def __init__(self,numerator , denominator):
    self.numerator = numerator
    self.denominator = denominator

  #magic method
  def __str__(self):
  #  return "hello"
     return "{}/{}".format(self.numerator, self.denominator)

  def __add__(self, other):
      temp_num = self.numerator *other.denominator + other.numerator *self.denominator
      temp_den =  self.denominator*other.denominator
      return "{}/{}".format(temp_num,temp_den)

  def __sub__(self, other):
      temp_num = self.numerator *other.denominator - other.numerator *self.denominator
      temp_den =  self.denominator * other.denominator
      return "{}/{}".format(temp_num,temp_den)
  def __mul__(self, other):
      temp_num = self.numerator *other.numerator
      temp_den =  self.denominator * other.denominator
      return "{}/{}".format(temp_num,temp_den)
  def __truediv__(self,other):
      temp_num = self.numerator *other.denominator
      temp_den = other.numerator *self.denominator
      return "{}/{}".format(temp_num,temp_den)

# %%
check = Fraction(3,4)

# %%
type(check)
# Out:
# __main__.Fraction

# %%
print(check)
# Out:
# 3/4

# %%
x = Fraction(8,9)
y = Fraction(9,7)
print(x)
print(y)
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 8/9
# 9/7
# 137/63
# -25/63
# 72/63
# 56/81

# %%
# reference variable
Atm()
# Out:
#       Hello, how would you like to proceed ?
#       1. enter 1 to create pin
#       2. enter 2 to deposite
#       3. enter 3 to withdraw
#       4. enter 4 to check balance
#       5. enter 5 to exit
#
#       5
#
#         exit

# %%
class Customer :
  def __init__(self,name, gender):
    self.name =  name;
    self.gender = gender

# function :
def greet(customer):
  if customer.gender == "male":
    print("hello", customer.name, "sir")

  else:
    print("hello", customer.name, "ma'am")

cust = Customer("prachi","female")

# %%
print(cust.name)
# Out:
# prachi

# %%
greet(cust) #function(object)
# Out:
# hello prachi ma'am

# %%
class Customers :
  def __init__(self,name):
    self.name =  name;

# function :
def greet(customer):
    print(id(customer))
    customer.name = "manohar"
    print(customer.name)
    print(id(customer))
cust2 = Customers("prachi")

# %%
print(id(cust2))
# Out:
# 136829263994928

# %%
greet(cust2)
# Out:
# 136829263994928
# manohar
# 136829263994928

# %% [markdown]
# both variable pointing on same point
# therefore both ids are same

# %%
# id of a and id b is same

# %%
id(cust2) # changed id since name changed
# Out:
# 136829263994928

# %%
print(cust2.name)
# Out:
# manohar

# %%
# since both were pointing to same object it will change in orginal name

# %%
def change(l):
  print(id(l))
  l.append(8)
  print(id(l))
l = [12,3,4]
change(l)
print(l)
change(l)
# Out:
# 136829555636544
# 136829555636544
# [12, 3, 4, 8]
# 136829555636544
# 136829555636544

# %%
# Cloning
change(l[:])
# Out:
# 136829555162432
# 136829555162432

# %%
print(l)
# Out:
# [12, 3, 4, 8, 8]

# %%
# meanwhile tuple are safe (unmutable)
